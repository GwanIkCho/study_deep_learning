# %%
from glob import glob
import os

root = './datasets/tom_and_jerry/original'

directories = glob(os.path.join(root, '*'))
directory_names = []
for directory in directories:
    directory_names.append(directory[directory.rindex('\\') + 1:])

print(directory_names)
# Out:
# ['jerry', 'tom', 'tom_jerry_0', 'tom_jerry_1']

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
root = './datasets/tom_and_jerry/original'
# root = './datasets/face/test/'
image_data_generator = ImageDataGenerator(rescale=1./255)

generator = image_data_generator.flow_from_directory(root, target_size=(244, 244), batch_size=32, class_mode='categorical')
print(generator.class_indices)
# generator_test = image_data_generator.flow_from_directory(root, target_size=(48, 48), batch_size=32, class_mode='categorical')
# print(generator_test.class_indices)
# Out:
# Found 5478 images belonging to 4 classes.
# {'jerry': 0, 'tom': 1, 'tom_jerry_0': 2, 'tom_jerry_1': 3}

# %%
import pandas as pd

tj_df = pd.DataFrame({'file_paths': generator.filepaths, 'targets': generator.classes})
tj_df
# Out:
#                                              file_paths  targets
# 0     ./datasets/tom_and_jerry/original\jerry\frame1...        0
# 1     ./datasets/tom_and_jerry/original\jerry\frame1...        0
# 2     ./datasets/tom_and_jerry/original\jerry\frame1...        0
# 3     ./datasets/tom_and_jerry/original\jerry\frame1...        0
# 4     ./datasets/tom_and_jerry/original\jerry\frame1...        0
# ...                                                 ...      ...
# 5473  ./datasets/tom_and_jerry/original\tom_jerry_1\...        3
# 5474  ./datasets/tom_and_jerry/original\tom_jerry_1\...        3
# 5475  ./datasets/tom_and_jerry/original\tom_jerry_1\...        3
# 5476  ./datasets/tom_and_jerry/original\tom_jerry_1\...        3
# 5477  ./datasets/tom_and_jerry/original\tom_jerry_1\...        3
#
# [5478 rows x 2 columns]

# %%
tj_df.loc[:, 'file_paths'] = tj_df.file_paths.apply(lambda x: x.replace('\\', '/'))
tj_df
# Out:
#                                              file_paths  targets
# 0     ./datasets/tom_and_jerry/original/jerry/frame1...        0
# 1     ./datasets/tom_and_jerry/original/jerry/frame1...        0
# 2     ./datasets/tom_and_jerry/original/jerry/frame1...        0
# 3     ./datasets/tom_and_jerry/original/jerry/frame1...        0
# 4     ./datasets/tom_and_jerry/original/jerry/frame1...        0
# ...                                                 ...      ...
# 5473  ./datasets/tom_and_jerry/original/tom_jerry_1/...        3
# 5474  ./datasets/tom_and_jerry/original/tom_jerry_1/...        3
# 5475  ./datasets/tom_and_jerry/original/tom_jerry_1/...        3
# 5476  ./datasets/tom_and_jerry/original/tom_jerry_1/...        3
# 5477  ./datasets/tom_and_jerry/original/tom_jerry_1/...        3
#
# [5478 rows x 2 columns]

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

root = './datasets/tom_and_jerry/original/'

idg = ImageDataGenerator(rescale=1./255)

generator = idg.flow_from_directory(
    root,
    target_size=(250, 250),
    batch_size=32,
    class_mode='categorical'
)

print(generator.class_indices)
# Out:
# Found 5478 images belonging to 4 classes.
# {'jerry': 0, 'tom': 1, 'tom_jerry_0': 2, 'tom_jerry_1': 3}

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.cvtColor(cv2.imread(generator.filepaths[124]), cv2.COLOR_BGR2RGB)

def show_image(image):
    plt.figure(figsize=(4, 4))
    plt.imshow(image)
    plt.axis('off')
    
show_image(image)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = \
train_test_split(tj_df.file_paths, tj_df.targets, stratify=tj_df.targets, test_size=0.2, random_state=124)

print(y_train.value_counts())
print(y_test.value_counts())
# Out:
# targets
# 1    1544
# 2    1222
# 0     992
# 3     624
# Name: count, dtype: int64
# targets
# 1    386
# 2    306
# 0    248
# 3    156
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_val, y_train, y_val = \
train_test_split(X_train, y_train, stratify=y_train, test_size=0.2, random_state=124)

print(y_train.value_counts())
print(y_val.value_counts())
# Out:
# targets
# 1    1235
# 2     977
# 0     794
# 3     499
# Name: count, dtype: int64
# targets
# 1    309
# 2    245
# 0    198
# 3    125
# Name: count, dtype: int64

# %%
import shutil

root = './datasets/tom_and_jerry/'

for file_path in X_train:
    animal_dir = file_path[len(root + 'original/'): file_path.rindex('/')]
    destination = os.path.join(root, 'train/' + animal_dir)

    if not os.path.exists(destination):
        os.makedirs(destination)

    shutil.copy2(file_path, destination)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 7
#       5 for file_path in X_train:
#       6     animal_dir = file_path[len(root + 'original/'): file_path.rindex('/')]
# ----> 7     destination = os.path.join(root, 'train/' + animal_dir)
#       9     if not os.path.exists(destination):
#      10         os.makedirs(destination)
#
# NameError: name 'os' is not defined

# %%
import shutil

root = './datasets/tom_and_jerry/'

for file_path in X_val:
    animal_dir = file_path[len(root + 'original/'): file_path.rindex('/')]
    destination = os.path.join(root, 'validation/' + animal_dir)

    if not os.path.exists(destination):
        os.makedirs(destination)

    shutil.copy2(file_path, destination)

# %%
import shutil

root = './datasets/tom_and_jerry/'

for file_path in X_test:
    animal_dir = file_path[len(root + 'original/'): file_path.rindex('/')]
    destination = os.path.join(root, 'test/' + animal_dir)

    if not os.path.exists(destination):
        os.makedirs(destination)

    shutil.copy2(file_path, destination)

# %%
import albumentations as A

def transform(image):
    aug = A.Compose([
        A.HorizontalFlip(p=0.5),
        A.VerticalFlip(p=0.5),
        A.OneOf([
            A.ColorJitter(p=0.5),
            A.RandomBrightnessContrast(brightness_limit=0.2, contrast_limit=0.2, p=0.5)
        ], p=1)
    ], p=0.2)
    return aug(image=image)['image']


# idg = ImageDataGenerator(preprocessing_function=transfrom, rescale=1./255)

# %%
def albumentations_preprocessing_function(image):
    image = image.astype(np.uint8)  # Ensure the image is in the right format
    image = transform(image=image)
    return image.astype(np.float16) / 255.0  # 이미지 타입을 float32로 변환하고 정규화

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator


IMAGE_SIZE = 244

train_dir = './datasets/tom_and_jerry/train'
validation_dir = './datasets/tom_and_jerry/validation'
test_dir = './datasets/tom_and_jerry/test'

train_data_generator = ImageDataGenerator(preprocessing_function=albumentations_preprocessing_function, rescale=1./255)
validation_data_generator = ImageDataGenerator(rescale=1./255)
test_data_generator = ImageDataGenerator(rescale=1./255)


train_generator = train_data_generator.flow_from_directory(
    train_dir,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=32,
    class_mode='categorical'
)

validation_generator = validation_data_generator.flow_from_directory(
    validation_dir,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=32,
    class_mode='categorical'
)

test_generator = test_data_generator.flow_from_directory(
    test_dir,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=32,
    class_mode='categorical'
)

print(train_generator.class_indices)
print(validation_generator.class_indices)
print(test_generator.class_indices)
# Out:
# Found 3505 images belonging to 4 classes.
# Found 877 images belonging to 4 classes.
# Found 1096 images belonging to 4 classes.
# {'jerry': 0, 'tom': 1, 'tom_jerry_0': 2, 'tom_jerry_1': 3}
# {'jerry': 0, 'tom': 1, 'tom_jerry_0': 2, 'tom_jerry_1': 3}
# {'jerry': 0, 'tom': 1, 'tom_jerry_0': 2, 'tom_jerry_1': 3}

# %%
import cv2
import matplotlib.pyplot as plt

image = cv2.cvtColor(cv2.imread(generator.filepaths[124]), cv2.COLOR_BGR2RGB)

def show_image(image):
    plt.figure(figsize=(4, 4))
    plt.imshow(image)
    plt.axis('off')
    
show_image(image)

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Conv2D, Dropout, Flatten, Activation, MaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from tensorflow.keras.regularizers import l1, l2
from tensorflow.keras.applications import InceptionV3

IMAGE_SIZE = 244

# InceptionV3 모델의 입력 텐서를 정의합니다.
input_tensor = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))

# InceptionV3 모델을 정의하고, include_top=False로 설정하여 최상위 Dense 레이어를 포함하지 않습니다.
base_model = InceptionV3(weights='imagenet', include_top=False, input_tensor=input_tensor)

# Global Average Pooling을 적용하여 2차원 텐서로 변환합니다.
x = GlobalAveragePooling2D()(base_model.output)

# Dense 레이어를 추가합니다.
x = Dense(512, activation='relu', kernel_initializer='he_normal')(x)

# 출력 레이어를 추가합니다.
output = Dense(4, activation='softmax', kernel_initializer='glorot_normal')(x)

# 모델을 정의합니다.
model = Model(inputs=input_tensor, outputs=output)

# 모델 구조를 출력합니다.
model.summary()
# Out:
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_8 (InputLayer)    │ (None, 244, 244, 3)       │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ conv2d_298 (Conv2D)           │ (None, 121, 121, 32)      │             864 │ input_layer_8[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ batch_normalization_298       │ (None, 121, 121, 32)      │              96 │ conv2d_298[0][0]           │
# ...

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy

model.compile(optimizer=Adam(), loss=CategoricalCrossentropy(), metrics=['acc'])

# %%
import numpy as np

history = model.fit(
    train_generator,
    batch_size=32,
    epochs=20,
    validation_data=validation_generator,
    callbacks=[mcp_cb, rlr_cb, ely_cb]
)
# Out:
# Epoch 1/20
# C:\Users\HANSUNG\AppData\Roaming\Python\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 371s 3s/step - acc: 0.6222 - loss: 1.1143 - val_acc: 0.3672 - val_loss: 12.7366 - learning_rate: 0.0010
# Epoch 2/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 341s 3s/step - acc: 0.8524 - loss: 0.4394 - val_acc: 0.2794 - val_loss: 43.2917 - learning_rate: 0.0010
# Epoch 3/20
#  10/110 ━━━━━━━━━━━━━━━━━━━━ 4:54 3s/step - acc: 0.8869 - loss: 0.3818
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[69], line 3
#       1 import numpy as np
# ...

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense , Conv2D , Dropout , Flatten , Activation, MaxPooling2D , GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam 
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau , EarlyStopping , ModelCheckpoint
from tensorflow.keras.regularizers import l1, l2

IMAGE_SIZE = 244

input_tensor = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))

# alpha를 크게 할 수록 Weight값을 작게 만들어서 과적합을 개선할 수 있고
# alpha를 작게 할 수록 Weight의 값이 커지지만, 어느 정도 상쇄하므로 과소적합을 개선할 수 있다.

x = Conv2D(filters=64, kernel_size=3, padding='same', kernel_initializer='he_normal')(input_tensor)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=64, kernel_size=3, padding='same', kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(2)(x)

x = Conv2D(filters=128, kernel_size=3, padding='same', kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=128, kernel_size=3, padding='same',kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(2)(x)

x = Conv2D(filters=256, kernel_size=3, padding='same', kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=256, kernel_size=3, padding='same',kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(2)(x)

x = Conv2D(filters=512, kernel_size=3, padding='same', kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=512, kernel_size=3, padding='same',kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(2)(x)

x = GlobalAveragePooling2D()(x)
x = Dropout(rate=0.5)(x)
x = Dense(300, activation='relu', kernel_initializer='he_normal')(x)
x = Dropout(rate=0.3)(x)
output = Dense(4, activation='softmax', kernel_initializer='glorot_normal')(x)

model = Model(inputs=input_tensor, outputs=output)

model.summary()
# Out:
# Model: "functional_17"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_10 (InputLayer)          │ (None, 244, 244, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_55 (Conv2D)                   │ (None, 244, 244, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_54               │ (None, 244, 244, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy

model.compile(optimizer=Adam(), loss=CategoricalCrossentropy(), metrics=['acc'])

# %%
import numpy as np

history = model.fit(
    train_generator,
    batch_size=32,
    epochs=20,
    validation_data=validation_generator,
    callbacks=[mcp_cb, rlr_cb, ely_cb]
)
# Out:
# Epoch 1/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1402s 13s/step - acc: 0.3825 - loss: 1.5330 - val_acc: 0.1881 - val_loss: 3.9984 - learning_rate: 0.0010
# Epoch 2/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1442s 13s/step - acc: 0.5174 - loss: 1.0351 - val_acc: 0.2805 - val_loss: 24.2430 - learning_rate: 0.0010
# Epoch 3/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1348s 12s/step - acc: 0.5539 - loss: 0.9572 - val_acc: 0.3535 - val_loss: 53.8675 - learning_rate: 0.0010

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense , Conv2D , Dropout , Flatten , Activation, MaxPooling2D , GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam 
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau , EarlyStopping , ModelCheckpoint
from tensorflow.keras.regularizers import l1, l2

IMAGE_SIZE = 244

input_tensor = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))

# alpha를 크게 할 수록 Weight값을 작게 만들어서 과적합을 개선할 수 있고
# alpha를 작게 할 수록 Weight의 값이 커지지만, 어느 정도 상쇄하므로 과소적합을 개선할 수 있다.

x = Conv2D(filters=32, kernel_size=3, padding='same', kernel_regularizer=l2(1e-4), kernel_initializer='he_normal')(input_tensor)
x = BatchNormalization()(x)
x = Activation('relu')(x)


x = Conv2D(filters=32, kernel_size=3, padding='same', kernel_regularizer=l2(1e-4), kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(2)(x)


x = Conv2D(filters=64, kernel_size=3, padding='same', kernel_regularizer=l2(1e-4),kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)


x = Conv2D(filters=64, kernel_size=3, padding='same', kernel_regularizer=l2(1e-4),kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(2)(x)

x = Flatten()(x)
x = Dropout(rate=0.5)(x)
x = Dense(200, activation='relu', kernel_initializer='he_normal')(x)
x = Dropout(rate=0.3)(x)
output = Dense(4, activation='softmax', kernel_initializer='glorot_normal')(x)

model = Model(inputs=input_tensor, outputs=output)

model.summary()
# Out:
# Model: "functional_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)           │ (None, 244, 244, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_24 (Conv2D)                   │ (None, 244, 244, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_24               │ (None, 244, 244, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy

# 이거 수정해야 합니다~

model.compile(optimizer=Adam(), loss=CategoricalCrossentropy(), metrics=['acc'])

# %%
import numpy as np

history = model.fit(
    train_generator,
    batch_size=32,
    epochs=20,
    validation_data=validation_generator,
    callbacks=[mcp_cb, rlr_cb, ely_cb]
)
# Out:
# Epoch 1/20
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 224s 2s/step - acc: 0.2915 - loss: 31.0997 - val_acc: 0.2782 - val_loss: 2.0131 - learning_rate: 0.0010
# Epoch 2/20
#   7/110 ━━━━━━━━━━━━━━━━━━━━ 3:11 2s/step - acc: 0.3879 - loss: 1.4048
# KeyboardInterrupt

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense , Conv2D , Dropout , Flatten , Activation, MaxPooling2D , GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam 
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau , EarlyStopping , ModelCheckpoint
from tensorflow.keras.regularizers import l1, l2

IMAGE_SIZE = 244

input_tensor = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))

# alpha를 크게 할 수록 Weight값을 작게 만들어서 과적합을 개선할 수 있고
# alpha를 작게 할 수록 Weight의 값이 커지지만, 어느 정도 상쇄하므로 과소적합을 개선할 수 있다.

x = Conv2D(filters=64, kernel_size=3, padding='same', kernel_regularizer=l2(1e-4), kernel_initializer='he_normal')(input_tensor)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=64, kernel_size=3, padding='same', kernel_regularizer=l2(1e-4), kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(2)(x)

x = Conv2D(filters=128, kernel_size=3, padding='same', kernel_regularizer=l2(1e-4), kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=128, kernel_size=3, padding='same',kernel_regularizer=l2(1e-4),kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(2)(x)

x = Conv2D(filters=256, kernel_size=3, padding='same', kernel_regularizer=l2(1e-4),kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=256, kernel_size=3, padding='same',kernel_regularizer=l2(1e-4),kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(2)(x)

x = Conv2D(filters=512, kernel_size=3, padding='same', kernel_regularizer=l2(1e-4),kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=512, kernel_size=3, padding='same',kernel_regularizer=l2(1e-4),kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(2)(x)

x = GlobalAveragePooling2D()(x)
x = Dropout(rate=0.5)(x)
x = Dense(100, activation='relu', kernel_initializer='he_normal')(x)
x = Dropout(rate=0.3)(x)
output = Dense(4, activation='softmax', kernel_initializer='glorot_normal')(x)

model = Model(inputs=input_tensor, outputs=output)

model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 244, 244, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 244, 244, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_8                │ (None, 244, 244, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy

# 이거 수정해야 합니다~

model.compile(optimizer=Adam(), loss=CategoricalCrossentropy(), metrics=['acc'])

# %%
import numpy as np

history = model.fit(
    train_generator,
    batch_size=32,
    epochs=20,
    validation_data=validation_generator,
    callbacks=[mcp_cb, rlr_cb]
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 import numpy as np
# ----> 3 history = model.fit(
#       4     train_generator,
#       5     batch_size=32,
#       6     epochs=20,
#       7     validation_data=validation_generator,
#       8     callbacks=[mcp_cb, rlr_cb]
#       9 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# ...

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense , Conv2D , Dropout , Flatten , Activation, MaxPooling2D , GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam 
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau , EarlyStopping , ModelCheckpoint
from tensorflow.keras.regularizers import l1, l2

IMAGE_SIZE = 244

input_tensor = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))

# alpha를 크게 할 수록 Weight값을 작게 만들어서 과적합을 개선할 수 있고
# alpha를 작게 할 수록 Weight의 값이 커지지만, 어느 정도 상쇄하므로 과소적합을 개선할 수 있다.

x = Conv2D(filters=64, kernel_size=3, padding='same', kernel_regularizer=l2(1e-3), kernel_initializer='he_normal')(input_tensor)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=64, kernel_size=3, padding='same', kernel_regularizer=l2(1e-3), kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(2)(x)

x = Conv2D(filters=128, kernel_size=3, padding='same', kernel_regularizer=l2(1e-3), kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=128, kernel_size=3, padding='same',kernel_regularizer=l2(1e-3),kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(2)(x)


x = Conv2D(filters=256, kernel_size=3, padding='same',kernel_regularizer=l2(1e-3),kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(2)(x)

x = Conv2D(filters=512, kernel_size=3, padding='same',kernel_regularizer=l2(1e-3),kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(2)(x)

x = GlobalAveragePooling2D()(x)
x = Dropout(rate=0.6)(x)
x = Dense(100, activation='relu', kernel_initializer='he_normal')(x)
x = Dropout(rate=0.4)(x)
output = Dense(4, activation='softmax', kernel_initializer='glorot_normal')(x)

model = Model(inputs=input_tensor, outputs=output)

model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 244, 244, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 244, 244, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 244, 244, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy

# 이거 수정해야 합니다~
model.load_weights('./callback_files/weights.002-12.3995-0.4494.weights.h5')
model.compile(optimizer=Adam(), loss=CategoricalCrossentropy(), metrics=['acc'])

# %%
import numpy as np

history = model.fit(
    train_generator,
    batch_size=32,
    epochs=8,
    validation_data=validation_generator,
    callbacks=[mcp_cb, rlr_cb]
)
# Out:
# Epoch 1/8
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1061s 10s/step - acc: 0.4628 - loss: 2.1997 - val_acc: 0.4002 - val_loss: 8.5428 - learning_rate: 0.0010
# Epoch 2/8
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 981s 9s/step - acc: 0.5120 - loss: 1.5971 - val_acc: 0.3523 - val_loss: 56.7776 - learning_rate: 0.0010
# Epoch 3/8
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 983s 9s/step - acc: 0.5425 - loss: 1.4054 - val_acc: 0.4071 - val_loss: 42.7632 - learning_rate: 0.0010
# Epoch 4/8
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 984s 9s/step - acc: 0.5664 - loss: 1.2954 - val_acc: 0.3523 - val_loss: 319.0261 - learning_rate: 1.0000e-04
# Epoch 5/8
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 979s 9s/step - acc: 0.5652 - loss: 1.2386 - val_acc: 0.3569 - val_loss: 454.2378 - learning_rate: 1.0000e-04
# Epoch 6/8
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 981s 9s/step - acc: 0.5812 - loss: 1.2009 - val_acc: 0.3523 - val_loss: 854.6526 - learning_rate: 1.0000e-05
# Epoch 7/8
# ...

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense , Conv2D , Dropout , Flatten , Activation, MaxPooling2D , GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam 
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.callbacks import ReduceLROnPlateau , EarlyStopping , ModelCheckpoint
from tensorflow.keras.regularizers import l1, l2

IMAGE_SIZE = 244

input_tensor = Input(shape=(IMAGE_SIZE, IMAGE_SIZE, 3))

# alpha를 크게 할 수록 Weight값을 작게 만들어서 과적합을 개선할 수 있고
# alpha를 작게 할 수록 Weight의 값이 커지지만, 어느 정도 상쇄하므로 과소적합을 개선할 수 있다.

x = Conv2D(filters=64, kernel_size=3, padding='same', kernel_regularizer=l2(1e-3), kernel_initializer='he_normal')(input_tensor)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=64, kernel_size=3, padding='same', kernel_regularizer=l2(1e-3), kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(2)(x)

x = Conv2D(filters=128, kernel_size=3, padding='same', kernel_regularizer=l2(1e-3), kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=128, kernel_size=3, padding='same',kernel_regularizer=l2(1e-3),kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(2)(x)

x = Conv2D(filters=256, kernel_size=3, padding='same',kernel_regularizer=l2(1e-3),kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=256, kernel_size=3, padding='same',kernel_regularizer=l2(1e-3),kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(2)(x)

x = Conv2D(filters=512, kernel_size=3, padding='same',kernel_regularizer=l2(1e-3),kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)

x = Conv2D(filters=512, kernel_size=3, padding='same',kernel_regularizer=l2(1e-3),kernel_initializer='he_normal')(x)
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = MaxPooling2D(2)(x)

x = GlobalAveragePooling2D()(x)
x = Dropout(rate=0.6)(x)
x = Dense(100, activation='relu', kernel_initializer='he_normal')(x)
x = Dropout(rate=0.4)(x)
output = Dense(4, activation='softmax', kernel_initializer='glorot_normal')(x)

model = Model(inputs=input_tensor, outputs=output)

model.summary()
# Out:
# Model: "functional_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_5 (InputLayer)           │ (None, 244, 244, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_34 (Conv2D)                   │ (None, 244, 244, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_34               │ (None, 244, 244, 64)        │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# ...

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy

# 이거 수정해야 합니다~

model.compile(optimizer=Adam(), loss=CategoricalCrossentropy(), metrics=['acc'])

# %%
import numpy as np

history = model.fit(
    train_generator,
    batch_size=32,
    epochs=8,
    validation_data=validation_generator,
    callbacks=[mcp_cb, rlr_cb]
)
# Out:
# Epoch 1/8
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1308s 12s/step - acc: 0.3166 - loss: 5.3812 - val_acc: 0.3227 - val_loss: 4.5633 - learning_rate: 0.0010
# Epoch 2/8
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1309s 12s/step - acc: 0.3663 - loss: 3.6642 - val_acc: 0.3535 - val_loss: 7.9159 - learning_rate: 0.0010
# Epoch 3/8
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1305s 12s/step - acc: 0.4835 - loss: 2.4986 - val_acc: 0.3387 - val_loss: 5.0690 - learning_rate: 0.0010
# Epoch 4/8
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1319s 12s/step - acc: 0.5184 - loss: 1.9356 - val_acc: 0.3558 - val_loss: 37.3051 - learning_rate: 1.0000e-04
# Epoch 5/8
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1329s 12s/step - acc: 0.5448 - loss: 1.8083 - val_acc: 0.3512 - val_loss: 71.2577 - learning_rate: 1.0000e-04
# Epoch 6/8
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1299s 12s/step - acc: 0.5640 - loss: 1.7232 - val_acc: 0.3523 - val_loss: 268.9298 - learning_rate: 1.0000e-05
# Epoch 7/8
# ...

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy

# 이거 수정해야 합니다~
model.load_weights('./callback_files/weights.006-533.1415-0.6049.weights.h5')

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# 이미지 로드 및 리사이즈
image = cv2.cvtColor(cv2.imread(generator.filepaths[1253]), cv2.COLOR_BGR2RGB)
resized_image = cv2.resize(image, (244, 244))

# 이미지 표시 함수 정의
def show_image(image):
    plt.figure(figsize=(4, 4))
    plt.imshow(image)
    plt.axis('off')

# 이미지 표시
show_image(resized_image)

# 이미지를 모델의 입력 형태에 맞게 차원 확장
input_data = np.expand_dims(resized_image, axis=0)

# 모델로부터 예측 확률 계산
pred_prob = model.predict(input_data)

# 가장 높은 확률을 가진 클래스 인덱스 가져오기
pred_class_index = np.argmax(pred_prob)

# 클래스 인덱스에 해당하는 레이블 가져오기
# 이 예시에서는 클래스 레이블을 알 수 없으므로 클래스 인덱스만 표시합니다.
pred_class_label = str(pred_class_index)

# 예측 클래스를 제목으로 표시
plt.title(pred_class_label)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
